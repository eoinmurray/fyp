# %%
# %pylab inline
from scipy.integrate import trapz
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def getData(name):
    data = np.loadtxt('./'+name+'.txt')
    x = data[:,0]
    y1 = data[:,1]
    y2 = data[:,2]
    return x, y1, y2

name = 'diag_norm'


x, y1, y2 = getData(name)
    
h = 12.5/2
l=int((x+neg).max()/(2*h))-1
    
idx = (x > -h) & (x < h)
idxl = idx[idx==True].size
xp = x[idx]
yp1 = y1[idx]
yp2 = y2[idx]

mult = 20
for i in xrange(int(xp.size/mult)):
    plt.plot(xp[mult*i: mult*(i+1)], yp1[mult*i: mult*(i+1)], 'bo-')

# plt.plot(xp, yp1, 'ro-', xp, yp2, 'bo-', markersize=1)
